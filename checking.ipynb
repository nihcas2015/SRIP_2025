# %%
import pandas as pd
import numpy as np

# %%
columns_df = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_Feature_Names.csv', header=None)
column_names = columns_df.iloc[0].tolist()


values_df1 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_1.csv', header=None)
values_df2 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_2.csv', header=None)
values_df3 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_3.csv', header=None)
values_df4 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_4.csv', header=None)
values_df5 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_5.csv', header=None)
values_df6 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_6.csv', header=None)
values_df7 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_7.csv', header=None)
values_df8 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_8.csv', header=None)
values_df9 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_9.csv', header=None)
values_df10 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_10.csv', header=None)
values_df12 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_11.csv', header=None)
values_df13 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_12.csv', header=None)
values_df14 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_13.csv', header=None)
values_df15 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_14.csv', header=None)
values_df16 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_15.csv', header=None)

combined_values = pd.concat([values_df1, values_df2,values_df3,values_df4,values_df5,values_df6,values_df7,values_df8,values_df9,values_df10,values_df12,values_df13,values_df14,values_df15,values_df16], ignore_index=True)

# Assign column names
combined_values.columns = column_names

# Final DataFrame
final_df = combined_values
# Out:
# C:\Users\nihca\AppData\Local\Temp\ipykernel_12140\2760000254.py:5: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df1 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_1.csv', header=None)
# C:\Users\nihca\AppData\Local\Temp\ipykernel_12140\2760000254.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   values_df2 = pd.read_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\Entire Dataset\UNSW_2018_IoT_Botnet_Dataset_2.csv', header=None)
# C:\Users\nihca\AppData\Local\Temp\ipykernel_12140\2760000254.py:19: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
final_df.columns
# Out:
#            pkSeqID         stime flgs proto            saddr  sport  \
# 0                1  1.526344e+09    e   arp    192.168.100.1    NaN
# 1                2  1.526344e+09    e   tcp    192.168.100.7    139
# 2                3  1.526344e+09    e   udp  192.168.100.149  51838
# 3                4  1.526344e+09    e   arp    192.168.100.4    NaN
# 4                5  1.526344e+09    e   udp   192.168.100.27  58999
# ...            ...           ...  ...   ...              ...    ...
# 14999995  14999996  1.528085e+09    e   udp  192.168.100.149  31088
# 14999996  14999997  1.528085e+09    e   udp  192.168.100.149  31089
# 14999997  14999998  1.528085e+09    e   udp  192.168.100.149  31090
# 14999998  14999999  1.528085e+09    e   udp  192.168.100.149  31091
# 14999999  15000000  1.528085e+09    e   udp  192.168.100.149  31092
#
#                    daddr  dport  pkts  bytes  ... spkts  dpkts  sbytes  \
# 0          192.168.100.3    NaN     4    240  ...     2      2     120
# ...

# %%
Normal1=final_df[final_df["category"]=="Theft"]

# %%
Theft1=final_df[final_df["category"]=="Theft"]

# %%
Reconnaissance1=final_df[final_df["category"]=="Reconnaissance"]

# %%
attack1=final_df[final_df["attack"]==0]

# %%
# Combine all category-specific dataframes
combined_all = pd.concat([Normal1, Theft1, Reconnaissance1, attack1], ignore_index=True)

# Remove duplicate rows (since some rows might appear in multiple categories)
combined_all = combined_all.drop_duplicates()

combined_all.isnull().sum()
# Display the final cleaned dataframe
# Out:
# pkSeqID               0
# stime                 0
# flgs                  0
# proto                 0
# saddr                 0
# daddr                 0
# pkts                  0
# bytes                 0
# state                 0
# ltime                 0
# seq                   0
# dur                   0
# mean                  0
# stddev                0
# sum                   0
# min                   0
# max                   0
# soui            1830796
# spkts                 0
# dpkts                 0
# sbytes                0
# dbytes                0
# rate                  0
# srate                 0
# drate                 0
# attack                0
# category              0
# subcategory           0
# dtype: int64

# %%
combined_all.to_csv(r'C:\Users\nihca\OneDrive\Documents\vscode\SRIP_2025\OneDrive_2025-06-20\cleaned_dataset\1.csv', index=False)

# %%
combined_all["soui"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'soui'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
